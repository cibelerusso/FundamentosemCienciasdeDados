# %% [markdown]
# <a href="https://colab.research.google.com/github/cibelerusso/FundamentosemCienciasdeDados/blob/main/Notebooks/Aula_Pratica_Fundamentos_em_Ci%C3%AAncias_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula prática - 5500004 Fundamentos em Ciências de Dados
#
# ## Profa Cibele Russo
#
# ## Objetivos da aula
# - revisar conceitos introdutórios de Ciência de Dados;
# - praticar interpretação de código em Python;
# - trabalhar com tipos básicos, laços, listas e compreensão de listas;
# - introduzir operações vetorizadas com NumPy;
# - praticar seleção, criação de colunas e agregação com Pandas.
#
# > **Orientação didática:** os exercícios priorizam leitura, interpretação, modificação e comparação de códigos, em linha com as listas e com o estilo da prova.

# %% [markdown]
# ## Como usar este notebook
#
# Em cada seção você encontrará:
# 1. uma breve explicação;
# 2. exemplos executáveis;
# 3. exercícios práticos;
# 4. espaços para registrar suas conclusões.

# %%
# Bibliotecas usadas na aula
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Conceitos iniciais
#
# Antes de programar, vale revisar alguns conceitos centrais.

# %% [markdown]
# ### Exercício 1: Conceitos
#
# Responda com suas palavras:
#
# 1. O que é Ciência de Dados?
# 2. Diferencie dado, informação e conhecimento.
# 3. Classifique cada situação como **descritiva, diagnóstica, preditiva ou prescritiva:**
#    - calcular a taxa de aprovação de uma disciplina;
#    - investigar fatores associados à evasão;
#    - prever quais alunos podem reprovar;
#    - sugerir ações para melhorar o desempenho.
#
# Preencha a célula abaixo.

# %%
respostas_conceitos = """
1.

2.

3.
- taxa de aprovação:
- fatores associados à evasão:
- prever reprovação:
- sugerir ações:
"""

print(respostas_conceitos)
# Out:
# 1.
#
# 2.
#
# 3.
# - taxa de aprovação:
# - fatores associados à evasão:
# - prever reprovação:
# - sugerir ações:

# %% [markdown]
# ## 2. Tipos de dados e interpretação de resultados

# %% [markdown]
# ### Exemplo 1 - Tipos básicos

# %%
idade = 18
altura = 1.60
nome = "Aline"
matriculado = True

print(type(idade))
print(type(altura))
print(type(nome))
print(type(matriculado))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Exercício 2 - Inspeção de tipos
#
# Sem alterar os nomes das variáveis, faça:
# 1. `idade` virar texto;
# 2. `altura` virar inteiro;
# 3. imprima novamente os tipos.
#
# Depois responda: o que significa dizer que Python tem tipagem dinâmica?

# %%
idade = 18
altura = 1.60
nome = "Aline"
matriculado = True

# idade = "18"
# altura = int(altura)

print(type(idade))
print(type(altura))
print(type(nome))
print(type(matriculado))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
import numpy as np

# arredondando
np.round(altura)
# Out:
# np.float64(2.0)

# %% [markdown]
# ### Exemplo 2 - Saídas diferentes

# %%
print("2" + "3")
print(2 + 3)
# Out:
# 23
# 5

# %% [markdown]
# ### Exercício 3 - Interpretação
#
# Explique por que as duas linhas anteriores produzem saídas diferentes.
# Depois teste também:
# - `"2" * 3`
# - `2 * 3`

# %%
print("2" * 3)
print(2 * 3)

explicacao_operacoes = """
Explique aqui a diferença entre operar com strings e com números.
"""
print(explicacao_operacoes)
# Out:
# 222
# 6
#
# Explique aqui a diferença entre operar com strings e com números.

# %% [markdown]
# ## 3. Laço `for` e cálculo de média

# %% [markdown]
# ### Exemplo 3 - Média com `for`

# %%
valores = [7.5, 8.0, 6.5, 9.0, 4.5]
soma = 0

for valor in valores:
    soma += valor

print("Soma = ", soma)

media = soma / len(valores)

print("Média =", media)
# Out:
# Soma =  35.5
# Média = 7.1

# %% [markdown]
# ### Exercício 4 - Rastreamento do código
#
# Responda:
# 1. o que o código faz;
# 2. qual é o papel da variável `soma`;
# 3. o que faz `len(valores)`;
# 4. qual é a saída final.
#
# Em seguida, altere a lista `valores` e teste com novos números.

# %%
valores = [10, 6, 8, 7, 9]
soma = 0

for valor in valores:
    soma += valor

media = soma / len(valores)
print("Média =", media)

interpretacao_media = """
1.
2.
3.
4.
"""
print(interpretacao_media)
# Out:
# Média = 8.0
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ### Exercício 5  Comparando abordagens para média
#
# Compare os dois códigos abaixo. Eles fazem a mesma coisa?

# %%
# Código A
valores = [2, 4, 6, 8]
soma = 0
for valor in valores:
    soma += valor
media_a = soma / len(valores)
print("media_a =", media_a)

# Código B
valores = [2, 4, 6, 8]
media_b = sum(valores) / len(valores)
print("media_b =", media_b)
# Out:
# media_a = 5.0
# media_b = 5.0

# %%
comparacao_medias = """
Explique em que sentido os códigos são equivalentes e qual parece mais claro para você.
"""
print(comparacao_medias)
# Out:
# Explique em que sentido os códigos são equivalentes e qual parece mais claro para você.

# %% [markdown]
# ## 4. Listas, `for` e list comprehension (compreensão de listas)

# %% [markdown]
# ### Exemplo 4 - Quadrados de uma lista

# %%
numeros = [1, 2, 3, 4, 5]
quadrados = []

for x in numeros:
    quadrados.append(x**2)

print(quadrados)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Exercício 6 - List comprehension
#
# Complete a versão com list comprehension para obter o mesmo resultado.

# %%
numeros = [1, 2, 3, 4, 5]

quadrados = [x**2 for x in numeros]

print(quadrados)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Exemplo 5 - Filtragem com compreensão de listas

# %%
numeros = [1, 2, 3, 4, 5, 6]
pares = [x for x in numeros if x % 2 == 0]
print(pares)
# Out:
# [2, 4, 6]

# %%
numeros = [1, 2, 3, 4, 5, 6]
impares = [x for x in numeros if x % 2 == 1]
print(impares)
# Out:
# [1, 3, 5]

# %%
numeros = [1, 2, 3, 4, 5, 6]
impares_quadrados = [x**2 for x in numeros if x % 2 == 1]
print(impares_quadrados)
# Out:
# [1, 9, 25]

# %%
numeros = [1, 2, 3, 4, 5, 6]
nova_lista = [x/10 for x in numeros if x % 2 == 1]
print(nova_lista)
# Out:
# [0.1, 0.3, 0.5]

# %% [markdown]
# ### Exercício 7 - Interpretando três códigos
#
# Os dois trechos abaixo atacam o mesmo problema: selecionar valores maiores que 10 e multiplicá-los por 3.
# Execute e compare.

# %%
# Código 1: for tradicional
numeros = [2, 5, 8, 11, 14, 17]
resultado1 = []

for numero in numeros:
    if numero > 10:
        resultado1.append(numero * 3)

print("resultado1 =", resultado1)
# Out:
# resultado1 = [33, 42, 51]

# %%
# Código 2: compreensão de listas
numeros = [2, 5, 8, 11, 14, 17]
resultado2 = [numero * 3 for numero in numeros if numero > 10]

print("resultado2 =", resultado2)
# Out:
# resultado2 = [33, 42, 51]

# %%
comparacao_listas = """
Explique:
1. o que faz o Código 1;
2. o que faz o Código 2;
3. se produzem o mesmo resultado;
4. qual abordagem parece mais concisa.
"""
print(comparacao_listas)

# %% [markdown]
# ## 5. NumPy: vetorização e máscara booleana

# %% [markdown]
# ### Exemplo 6 - Soma direta em array

# %%
a = np.array([10, 20, 30, 40])
print(a + 5)

# %% [markdown]
# ### Exercício 8 - Vetorização
#
# Explique por que não foi necessário usar `for` no exemplo anterior.
# Depois reescreva mentalmente o algoritmo em linguagem natural.

# %%
explicacao_vetorizacao = """
Escreva aqui sua explicação.
"""
print(explicacao_vetorizacao)

# %% [markdown]
# ### Exemplo 7 - Máscara booleana

# %%
a = np.array([10, 20, 30, 40])
print(a[a > 20])

# %% [markdown]
# ### Exercício 9 - Mesmo problema em listas e em NumPy
#
# Compare agora três abordagens para o mesmo problema.

# %%
# Lista + for
numeros = [2, 5, 8, 11, 14, 17]
resultado_for = []

for numero in numeros:
    if numero > 10:
        resultado_for.append(numero * 3)

print("resultado_for =", resultado_for)

# Lista + compreensão
numeros = [2, 5, 8, 11, 14, 17]
resultado_comp = [numero * 3 for numero in numeros if numero > 10]
print("resultado_comp =", resultado_comp)

# NumPy
a = np.array([2, 5, 8, 11, 14, 17])
resultado_np = a[a > 10] * 3
print("resultado_np =", resultado_np)

# %%
comparacao_numpy = """
Compare as três abordagens em termos de:
- clareza;
- concisão;
- adequação para bases maiores.
"""
print(comparacao_numpy)

# %% [markdown]
# ### Exercício 10 - Estrutura do array
#
# Execute e interprete:

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
print("shape:", a.shape)
print("ndim:", a.ndim)
print("dtype:", a.dtype)

# %%
interpretacao_array = """
Explique o significado de shape, ndim e dtype.
"""
print(interpretacao_array)

# %% [markdown]
# ## 6. Pandas: seleção, filtros e agregação

# %% [markdown]
# ### Exemplo 8 - Criando um DataFrame

# %%
df = pd.DataFrame({
    "aluno": ["Ana", "Bruno", "Carla", "Diego", "Eva"],
    "nota": [8.5, 4.0, 6.5, 9.0, 5.5],
    "frequencia": [90, 72, 80, 95, 68]
})

df

# %% [markdown]
# ### Exercício 11 - Filtros
#
# Execute os comandos e interprete os resultados.

# %%
print(df[df["nota"] >= 7])
print()
print(df[df["frequencia"] < 75])

# %%
interpretacao_filtros = """
Explique o que cada filtro faz.
"""
print(interpretacao_filtros)

# %% [markdown]
# ### Exercício 12 - Criação de coluna
#
# Complete a lógica da coluna `situacao`:
# - Aprovado: nota >= 7
# - Recuperação: 5 <= nota < 7
# - Reprovado: nota < 5

# %%
df = pd.DataFrame({
    "aluno": ["Ana", "Bruno", "Carla", "Diego", "Eva"],
    "nota": [8.5, 4.0, 6.5, 9.0, 5.5],
    "frequencia": [90, 72, 80, 95, 68]
})

def classificar_nota(nota):
    if nota >= 7:
        return "Aprovado"
    elif nota >= 5:
        return "Recuperação"
    else:
        return "Reprovado"

df["situacao"] = df["nota"].apply(classificar_nota)
df
# Out:
#    aluno  nota  frequencia     situacao
# 0    Ana   8.5          90     Aprovado
# 1  Bruno   4.0          72    Reprovado
# 2  Carla   6.5          80  Recuperação
# 3  Diego   9.0          95     Aprovado
# 4    Eva   5.5          68  Recuperação

# %% [markdown]
# ### Exercício 13 - Medidas resumo e contagem

# %%
# Calculando a média das notas
media_notas = df["nota"].mean()

# Contando quantos alunos há em cada categoria da coluna situacao
contagem_situacao = df["situacao"].value_counts()

print("Média das notas:", media_notas)
print()
print(contagem_situacao)
# Out:
# Média das notas: 6.7
#
# situacao
# Aprovado       2
# Recuperação    2
# Reprovado      1
# Name: count, dtype: int64

# %% [markdown]
# ### Exemplo 9 - Coluna nova de forma idiomática

# %%
df["nota_ajustada"] = df["nota"] + 0.5
df

# %% [markdown]
# ### Exercício 14 - Discussão conceitual
#
# Responda:
# 1. Por que Pandas costuma ser mais apropriado do que listas puras para dados tabulares?
# 2. Qual a vantagem de operações por coluna?
# 3. Em que situações NumPy e Pandas se complementam?

# %%
discussao_pandas = """
1.

2.

3.
"""
print(discussao_pandas)

# %% [markdown]
# ### Exercício 15 - Análise simples de uma turma
#
# Use a tabela abaixo para responder ao que se pede.

# %%
turma = pd.DataFrame({
    "nome": ["Alice", "Beto", "Caio", "Dora", "Ester", "Fábio", "Gabi"],
    "nota": [9.0, 5.5, 3.0, 7.5, 6.0, 8.0, 4.5],
    "faltas": [2, 8, 12, 3, 6, 1, 10]
})

turma

# %% [markdown]
# Tarefas:
# 1. calcule a média da coluna `nota`;
# 2. filtre alunos com nota maior ou igual a 7;
# 3. crie uma coluna `situacao` com aprovado, recuperação e reprovado;
# 4. conte quantos alunos há em cada situação;
# 5. escreva, em texto, uma pequena interpretação dos resultados.
